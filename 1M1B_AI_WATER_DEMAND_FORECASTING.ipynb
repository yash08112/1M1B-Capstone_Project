# %%
import pandas as pd
import numpy as np
from skimpy import skim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
wdf=pd.read_csv(r"C:\Users\yash0\OneDrive\Desktop\New folder\Cursor projects\Modified_Campus_Water_Full_Feature_Set.csv")

# %%
skim(wdf)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 36500  │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 9      │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 2     │                                                          │
# ...

# %%
wdf.head()
# Out:
#     Timestamp  Campus_Location  Ambient_Temp_C Activity_Level  \
# 0  2025-01-01  Central_Canteen            22.1         Medium
# 1  2025-01-02    Boys_Hostel_C            41.0         Medium
# 2  2025-01-03  Central_Canteen            26.4           High
# 3  2025-01-04   Indoor_Stadium            31.4         Medium
# 4  2025-01-05   Campus_Laundry            35.7            Low
#
#    Total_Demand_Liters  Day_of_Week  Month Weekend  Academic_Status
# 0               1200.0            2      1      YES         Regular
# 1               1986.0            3      1       NO         Regular
# 2               1480.0            4      1       NO         Regular
# 3               1580.0            5      1      YES         Regular
# 4               2187.0            6      1      YES         Regular

# %%
wdf["Month"].unique
# Out:
# <bound method Series.unique of 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 36495    12
# 36496    12
# 36497    12
# 36498    12
# 36499    12
# Name: Month, Length: 36500, dtype: int64>

# %%
wdf["Timestamp"]=pd.to_datetime(wdf["Timestamp"])

# %%
import matplotlib.pyplot as plt

activity_counts = wdf['Activity_Level'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(activity_counts, labels=activity_counts.index, autopct='%1.1f%%')
plt.title("Water Usage by Activity Level")
plt.show()

# %% [markdown]
# ### ⬆️ This shows the activity percentage of water in the campus between "low","Medium","High"

# %% [markdown]
# ## ----Campus Location Usage----

# %%
top_locations = wdf['Campus_Location'].value_counts().head(5)

plt.figure(figsize=(7,7))
plt.pie(top_locations, labels=top_locations.index, autopct='%1.1f%%')
plt.title("Top 5 Campus Locations by Usage")
plt.show()

# %%
wdf["Activity_Level"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
wdf["Activity_Level"]=wdf["Activity_Level"].replace({
    "Low":0,
    "Medium":1,
    "High":2
})

# %% [markdown]
# ## Breaking TimeStamp

# %%
wdf['Year']=wdf['Timestamp'].dt.year
wdf['Month']=wdf['Timestamp'].dt.month
wdf['Day']=wdf['Timestamp'].dt.day
wdf['Day_Of_week']=wdf['Timestamp'].dt.day_name()

# %%
wdf['Weekend'] = wdf['Day_Of_week'].isin(['Saturday', 'Sunday']).astype(int)
# This will convert "Sat","Sun" to 1 and rest 0

# %%
wdf['Week'] = wdf['Timestamp'].dt.isocalendar().week

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Summer'
    elif month in [6, 7, 8]:
        return 'Monsoon'
    else:
        return 'Post-Monsoon'

wdf['Season'] = wdf['Month'].apply(get_season)

# %%
wdf.head()
# Out:
#    Timestamp  Campus_Location  Ambient_Temp_C  Activity_Level  \
# 0 2025-01-01  Central_Canteen            22.1               1
# 1 2025-01-02    Boys_Hostel_C            41.0               1
# 2 2025-01-03  Central_Canteen            26.4               2
# 3 2025-01-04   Indoor_Stadium            31.4               1
# 4 2025-01-05   Campus_Laundry            35.7               0
#
#    Total_Demand_Liters  Day_of_Week  Month Weekend  Academic_Status  Year  \
# 0               1200.0            2      1      YES         Regular  2025
# 1               1986.0            3      1       NO         Regular  2025
# 2               1480.0            4      1       NO         Regular  2025
# 3               1580.0            5      1      YES         Regular  2025
# 4               2187.0            6      1      YES         Regular  2025
#
#    Day Day_Of_week  Weekend  Week  Season
# 0    1   Wednesday        0     1  Winter
# 1    2    Thursday        0     1  Winter
# ...

# %%
wdf['Weekend'].value_counts()
# Out:
# Weekend
# 0    26100
# 1    10400
# Name: count, dtype: int64

# %%
wdf.drop('Day_of_Week', axis=1, inplace=True)

# %% [markdown]
# ## -------Weekend vs Weekday---------

# %%
plt.figure(figsize=(12,9))
sns.barplot(x="Weekend",y="Total_Demand_Liters",data=wdf)
plt.title("Weekend vs Weekday Water Demand")
plt.show()

# %% [markdown]
# ### ⬆️ "0"= Weekday / "1"=Weekend

# %% [markdown]
# ## ------Month-wise Trend------

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Month', y='Total_Demand_Liters', data=wdf)
plt.title("Monthly Water Demand Trend")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Ambient_Temp_C', y='Total_Demand_Liters', data=wdf)
plt.title("Temperature vs Water Demand")
plt.show()

# %% [markdown]
# # ------Encoding-------

# %%
wdf = pd.get_dummies(wdf, 
                     columns=['Campus_Location', 'Day_Of_week', 'Season', 'Academic_Status'], 
                     drop_first=True)

# %%
bol=wdf.select_dtypes(include=['bool']).columns
wdf[bol]=wdf[bol].astype(int)

# %%
wdf.head()
# Out:
#    Timestamp  Ambient_Temp_C  Activity_Level  Total_Demand_Liters  Month  \
# 0 2025-01-01            22.1               1               1200.0      1
# 1 2025-01-02            41.0               1               1986.0      1
# 2 2025-01-03            26.4               2               1480.0      1
# 3 2025-01-04            31.4               1               1580.0      1
# 4 2025-01-05            35.7               0               2187.0      1
#
#   Weekend   Year  Day  Weekend  Week  ...  Day_Of_week_Saturday  \
# 0      YES  2025    1        0     1  ...                     0
# 1       NO  2025    2        0     1  ...                     0
# 2       NO  2025    3        0     1  ...                     0
# 3      YES  2025    4        1     1  ...                     1
# 4      YES  2025    5        1     1  ...                     0
#
#    Day_Of_week_Sunday  Day_Of_week_Thursday  Day_Of_week_Tuesday  \
# 0                   0                     0                    0
# ...

# %%
wdf['Total_Demand_Liters'].max
# Out:
# <bound method Series.max of 0        1200.0
# 1        1986.0
# 2        1480.0
# 3        1580.0
# 4        2187.0
#           ...
# 36495    2241.0
# 36496      88.5
# 36497    2637.0
# 36498    1115.0
# 36499    1177.5
# Name: Total_Demand_Liters, Length: 36500, dtype: float64>

# %%
wdf.drop(columns='Timestamp',inplace=True)

# %%
wdf['Activity_Level'].unique()
# Out:
# array([1, 2, 0])

# %% [markdown]
# # -------Feature Selection---------

# %%
y = wdf['Total_Demand_Liters']

X = wdf.drop('Total_Demand_Liters', axis=1)

# %%
X_numeric = X.select_dtypes(include=['int64', 'float64'])

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
X_scaled = scale.fit_transform(X_numeric)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 249.4727246068005
# RMSE: 343.20085524341994
# R2 Score: 0.785353978760397

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# ### The model achieved an R² score of around 0.78, indicating strong predictive performance. The MAE of ~249 liters shows that the average prediction error is relatively low, making the model reliable for real-world water demand forecasting.

# %% [markdown]
# # ------Applying Random Forest--------

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("RF R2:", r2_score(y_test, y_pred_rf))
# Out:
# RF R2: 0.9845019345063547

# %% [markdown]
# # --------Feature Importance----------

# %%
import pandas as pd

importance = rf.feature_importances_
features = X_numeric.columns

feat_imp = pd.Series(importance, index=features).sort_values(ascending=False)

print(feat_imp.head(10))
# Out:
# Academic_Status_Vacation             0.234026
# Campus_Location_Central_Library      0.223998
# Campus_Location_Campus_Laundry       0.126292
# Ambient_Temp_C                       0.089303
# Activity_Level                       0.068608
# Weekend                              0.051771
# Campus_Location_Garden_Irrigation    0.042537
# Campus_Location_Boys_Hostel_C        0.035202
# Campus_Location_Main_Hostel_A        0.034584
# Campus_Location_Girls_Hostel_B       0.033938
# dtype: float64

# %% [markdown]
# ### The analysis shows that campus location plays the most significant role in water demand, especially areas like Central Library and Campus Laundry. Academic status and activity level also influence usage patterns, while temperature has a moderate impact. This indicates that both human activity and environmental factors drive water consumption.

# %%
import matplotlib.pyplot as plt

feat_imp.head(10).plot(kind='bar')
plt.title("Top Features Affecting Water Demand")
plt.ylabel("Importance")
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Random Forest performed better than Linear Regression, indicating that non-linear relationships exist in water demand patterns.
